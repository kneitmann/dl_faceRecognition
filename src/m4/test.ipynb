# %%
from loadData import createDataset, generate_image_pairs, generate_image_triplets
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

training_data_path = '../../data/m4_manyOne/testKnownShort/'

# Data parameters
image_height = 160
image_width = 160

# Creating the training and validation dataset
train_images, train_labels = createDataset(training_data_path, (image_height, image_width))

# Creating the training image pairs and the corrsponding labels
train_image_pairs, train_pair_labels = generate_image_triplets(train_images, train_labels)

# np.random.seed(123)
# np.random.shuffle(train_image_pairs)
# np.random.seed(123)
# np.random.shuffle(train_pair_labels)

fig, axes = plt.subplots(10, 2, figsize=(15, 15))
for i in range(20):
    img_pair = train_image_pairs[i]
    ax = axes[i // 2, i % 2]
    ax.imshow(tf.concat([img_pair[0].astype('int32'), img_pair[1].astype('int32')], axis=1))
    ax.set_title(int(train_pair_labels[i][0]))
    ax.set_axis_off()

plt.tight_layout(rect=(0, 0, 1.5, 1.5))
plt.show()
